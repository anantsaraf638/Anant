# %%
# !pip install tensorflow matplotlib pillow

# %%
# !pip install torch torchvision pillow matplotlib

# %%
# After your preprocessing steps

import tensorflow as tf
import matplotlib.pyplot as plt

content_path = r"C:\Users\hp\OneDrive\download.jpeg"   # Update with actual file path
style_path = r"C:\Users\hp\OneDrive\download (1).jpeg"

# Example image loading (assuming preprocess and paths already set)
content = preprocess(content_path, (224, 224))
style = preprocess(style_path, (224, 224))

def deprocess(img):
    img = img.reshape((224, 224, 3))
    img[:, :, 0] += 103.939
    img[:, :, 1] += 116.779
    img[:, :, 2] += 123.68
    img = img[:, :, ::-1]  # BGR to RGB
    img = np.clip(img, 0, 255).astype('uint8')
    return img

# Example: show a preprocessed content image
plt.imshow(deprocess(content[0].copy()))
plt.axis('off')
plt.show()
